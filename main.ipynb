# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

data=pd.read_csv("health_lifestyle_classification.csv")
data
# Out:
#        survey_code  age  gender      height     weight        bmi  \
# 0                1   56    Male  173.416872  56.886640  18.915925
# 1                2   69  Female  163.207380  97.799859  36.716278
# 2                3   46    Male  177.281966  80.687562  25.673050
# 3                4   32  Female  172.101255  63.142868  21.318480
# 4                5   60  Female  163.608816  40.000000  14.943302
# ...            ...  ...     ...         ...        ...        ...
# 99995        99996   53    Male  177.202253  54.303671  17.293811
# 99996        99997   22    Male  180.802297  40.033853  12.246712
# 99997        99998   37    Male  185.540653  84.536847  24.556580
# 99998        99999   72  Female  181.796786  56.923335  17.223362
# 99999       100000   37    Male  175.716378  93.017286  30.125841
#
#        bmi_estimated  bmi_scaled  bmi_corrected  waist_size  ...  \
# 0          18.915925   56.747776      18.989117   72.165130  ...
# ...

# %%
data.describe()

# df.isnull().sum()
# Out:
#          survey_code            age         height         weight  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    50000.500000      48.525990     170.023707      70.064862
# std     28867.657797      17.886768       9.982798      14.693667
# min         1.000000      18.000000     140.000000      40.000000
# 25%     25000.750000      33.000000     163.306615      59.856938
# 50%     50000.500000      48.000000     170.016778      69.924141
# 75%     75000.250000      64.000000     176.728920      80.027418
# max    100000.000000      79.000000     210.000000     139.250894
#
#                  bmi  bmi_estimated     bmi_scaled  bmi_corrected  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       24.493876      24.493876      73.481627      24.494140
# std         5.951069       5.951069      17.853206       5.954184
# min         9.988495       9.988495      29.965484       9.893845
# ...

# %%
data=data.drop(["insurance","bmi_estimated","bmi_scaled","bmi_corrected","family_history","exercise_type","sleep_quality","family_history","job_type","environmental_risk_score","electrolyte_level","gene_marker_flag","mental_health_support","education_level"],axis=1)

# %%
data.describe()
# Out:
#          survey_code            age         height         weight  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    50000.500000      48.525990     170.023707      70.064862
# std     28867.657797      17.886768       9.982798      14.693667
# min         1.000000      18.000000     140.000000      40.000000
# 25%     25000.750000      33.000000     163.306615      59.856938
# 50%     50000.500000      48.000000     170.016778      69.924141
# 75%     75000.250000      64.000000     176.728920      80.027418
# max    100000.000000      79.000000     210.000000     139.250894
#
#                  bmi     waist_size  blood_pressure    heart_rate  \
# count  100000.000000  100000.000000    92331.000000  85997.000000
# mean       24.493876      84.933043      119.980149     74.969177
# std         5.951069      12.040314       15.015503      9.941668
# min         9.988495      34.093185       59.128168     34.745092
# ...

# %%
data.isnull().sum()
# Out:
# survey_code                    0
# age                            0
# gender                         0
# height                         0
# weight                         0
# bmi                            0
# waist_size                     0
# blood_pressure              7669
# heart_rate                 14003
# cholesterol                    0
# glucose                        0
# insulin                    15836
# sleep_hours                    0
# work_hours                     0
# physical_activity              0
# daily_steps                 8329
# calorie_intake                 0
# sugar_intake                   0
# alcohol_consumption        42387
# smoking_level                  0
# water_intake                   0
# screen_time                    0
# stress_level                   0
# mental_health_score            0
# occupation                     0
# income                      8470
# diet_type                      0
# device_usage                   0
# ...

# %%
# data.to_csv('health_data_updated.csv', index=True)

means=data.mean()
means
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # data.to_csv('health_data_updated.csv', index=True)
# ----> 3 means=data.mean()
#       4 means
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
# ...
